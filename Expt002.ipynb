# %%
a=input("Enter no. 1 :")
b=input("Enter no. 2:")
c=a+b
print(c)
d=int (input("Enter the number :"))
print(d)
# Out:
# Enter no. 1 :3
# Enter no. 2:4
# 34
# Enter the number :6
# 6

# %%
# CONCATENATION
str1 ="dkte"
str2 ="college"
print(str1+ str2)
# Out:
# dktecollege

# %%
#len()
str1="dkte"
print(len(str1))
str2="AB CD"
print(len(str2))
# Out:
# 4
# 5

# %%
#INDEXING
str1="DKTE"
print(str1[0])
print(str1[1])
print(str1[2])
print(str1[3])
print(str1[6])
# Out:
# D
# K
# T
# E
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_9723/329626365.py in <cell line: 0>()
#       5 print(str1[2])
#       6 print(str1[3])
# ----> 7 print(str1[6])
#
# IndexError: string index out of range

# %%
#SLICING
str1="DKTE"
print(str1[1:3])
print(str1[:3])
print(str1[2:])
print(str1[:])
print(str1[-1:])
print(str1[:-3])
# Out:
# KT
# DKT
# TE
# DKTE
# E
# D

# %%
#STRING'S LIBRARY FUNCTIONS
str1="I am Sush"
print(str1.startswith("I"))
print(str1.endswith("h"))

str2="dkTe"
print(str2.upper())
print(str2.lower())

print(str2.title())

print(str2.isalpha())
print(str2.isupper())
print(str2.islower())

city= "Ichalkaranji"
print(city.find("a"))
print(city.find("i"))
print(city.count("a"))
print(city.replace("a","d"))
# Out:
# True
# True
# DKTE
# dkte
# Dkte
# True
# False
# False
# 3
# 11
# 3
# Ichdlkdrdnji
